# %% [markdown]
# # Creating and avaluating a classifier.

# %% [markdown]
# We can roughly guess that the distribution will not be evenly distributed under and over the 50K demarcation, but that the boundary will be in one of the extremums. We also have both continuous and categorical data. For this reason, we want to use a method based on decision trees because it generally works well with this kind of mixed data. We want to try boosting and bagging strategies. For boosting, Gradient Boosting.
#
# We try this because it minimize the bias in the construction of the bagging decision trees for Extremely randomized forests and Random Forests, and because it absorbs the bias with the number of trees in boosting. However, since we do not have a live performance imperative, we might not use boosting which is very fast but less accurate.
#
# We use Gini for training. In order to estimate our predictor's performance, we will use accuracy, precision and recall. We might try cross validation as well.

# %%
import pandas as pd
import os

# %%
dir_path = '/Users/macbookpro/Documents/'
cols = ['age',
        'workclass',
        'fnlwgt',
        'education',
        'education-num',
        'marital-status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'capital-gain',
        'capital-loss',
        'hours-per-week',
        'native-country',
        'class'
       ]
data = pd.read_csv(dir_path + 'adult.data.csv', names=cols)

# %%
data = data.sample(frac=1)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 11357   24            Private  179423        HS-grad              9
# 27665   30                  ?  103651           11th              7
# 19293   51            Private  280093        HS-grad              9
# 9305    28            Private  162343        HS-grad              9
# 7115    22            Private   71469     Assoc-acdm             12
# 7885    25            Private  108658        HS-grad              9
# 8399    19            Private  231962        HS-grad              9
# 31258   27            Private  492263           10th              6
# 22341   29            Private  354558        HS-grad              9
# 26130   53   Self-emp-not-inc   46704        Masters             14
# 3320    46            Private  180695   Some-college             10
# 12175   21                  ?  479482   Some-college             10
# 21624   41       Self-emp-inc  125831        HS-grad              9
# 10839   22            Private  244773        HS-grad              9
# 1201    30          Local-gov  235271      Bachelors             13
# 25597   61   Self-emp-not-inc  117387           11th              7
# 1219    38            Private  200818    Prof-school             15
# 13803   63            Private  176696        HS-grad              9
# 20504   62   Self-emp-not-inc  215944        5th-6th              3
# 21062   21            Private   86625   Some-college             10
# 6132    44            Private   45093        HS-grad              9
# 30926   56            Private  107165        HS-grad              9
# 28780   21          Local-gov  193130   Some-college             10
# 7442    24            Private  180060     Assoc-acdm             12
# 7551    46          State-gov  421223   Some-college             10
# 27022   63                  ?   29859        HS-grad              9
# 27703   25            Private   97789      Bachelors             13
# 537     29            Private  102345      Assoc-voc             11
# 13512   62          Local-gov  197218        HS-grad              9
# 15654   50            Private  211319      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 4604    26            Private  171114      Assoc-voc             11
# 7780    39            Private  198097      Bachelors             13
# 28159   62          Local-gov  115763        Masters             14
# 12991   76                  ?   79445           10th              6
# 17924   45            Private  178341        Masters             14
# 27074   42          Local-gov  255847        HS-grad              9
# 13886   50            Private  189107        HS-grad              9
# 22557   55   Self-emp-not-inc   95149   Some-college             10
# 7171    24            Private  209770      Bachelors             13
# 29426   45            Private   30457      Bachelors             13
# 1608    39            Private  379350           10th              6
# 5786    43            Private  361280           10th              6
# 14972   27            Private  255476        5th-6th              3
# 14548   24                  ?  212300        HS-grad              9
# 22447   43        Federal-gov  195897        HS-grad              9
# 6383    46       Self-emp-inc  191978        Masters             14
# 20831   37            Private  359131        HS-grad              9
# 21441   32   Self-emp-not-inc  180303      Bachelors             13
# 8586    23            Private  148315   Some-college             10
# 7390    50            Private  378747        HS-grad              9
# 7064    56   Self-emp-not-inc  233312        Masters             14
# 21908   36            Private   41017   Some-college             10
# 18864   53            Private  103586      Bachelors             13
# 4139    29            Private  205903        HS-grad              9
# 22434   45            Private  168262        Masters             14
# 24616   41            Private   55854      Bachelors             13
# 23015   42            Private  212894      Bachelors             13
# 17531   21                  ?  121694        7th-8th              4
# 18928   25            Private  190628   Some-college             10
# 20990   60            Private  226949        HS-grad              9
#
#             marital-status          occupation     relationship  \
# 11357        Never-married        Adm-clerical        Own-child
# 27665   Married-civ-spouse                   ?          Husband
# 19293            Separated        Adm-clerical   Other-relative
# 9305         Never-married       Other-service    Not-in-family
# 7115         Never-married               Sales        Own-child
# 7885         Never-married     Exec-managerial    Not-in-family
# 8399         Never-married       Other-service        Unmarried
# 31258            Separated   Machine-op-inspct        Own-child
# 22341   Married-civ-spouse               Sales          Husband
# 26130   Married-civ-spouse      Prof-specialty          Husband
# 3320         Never-married        Adm-clerical        Own-child
# 12175        Never-married                   ?        Own-child
# 21624   Married-civ-spouse               Sales          Husband
# 10839        Never-married               Sales        Own-child
# 1201    Married-civ-spouse      Prof-specialty          Husband
# 25597   Married-civ-spouse     Exec-managerial          Husband
# 1219    Married-civ-spouse      Prof-specialty          Husband
# 13803   Married-civ-spouse        Craft-repair          Husband
# 20504   Married-civ-spouse     Farming-fishing          Husband
# 21062        Never-married   Machine-op-inspct        Own-child
# 6132    Married-civ-spouse     Farming-fishing          Husband
# 30926   Married-civ-spouse   Handlers-cleaners          Husband
# 28780        Never-married        Adm-clerical    Not-in-family
# 7442         Never-married        Craft-repair    Not-in-family
# 7551         Never-married     Exec-managerial    Not-in-family
# 27022   Married-civ-spouse                   ?          Husband
# 27703        Never-married               Sales        Own-child
# 537              Separated        Craft-repair    Not-in-family
# 13512              Widowed       Other-service    Not-in-family
# 15654   Married-civ-spouse     Exec-managerial          Husband
# ...                    ...                 ...              ...
# 4604             Separated        Adm-clerical        Unmarried
# 7780              Divorced     Exec-managerial    Not-in-family
# 28159   Married-civ-spouse      Prof-specialty             Wife
# 12991   Married-civ-spouse                   ?          Husband
# 17924   Married-civ-spouse      Prof-specialty          Husband
# 27074   Married-civ-spouse    Transport-moving          Husband
# 13886   Married-civ-spouse   Machine-op-inspct          Husband
# 22557   Married-civ-spouse    Transport-moving          Husband
# 7171         Never-married      Prof-specialty    Not-in-family
# 29426   Married-civ-spouse     Exec-managerial          Husband
# 1608    Married-civ-spouse        Craft-repair          Husband
# 5786    Married-civ-spouse        Craft-repair          Husband
# 14972        Never-married       Other-service   Other-relative
# 14548            Separated                   ?    Not-in-family
# 22447   Married-civ-spouse     Farming-fishing          Husband
# 6383    Married-civ-spouse     Exec-managerial          Husband
# 20831             Divorced        Craft-repair        Unmarried
# 21441             Divorced        Craft-repair        Unmarried
# 8586             Separated        Craft-repair        Own-child
# 7390    Married-civ-spouse    Transport-moving          Husband
# 7064    Married-civ-spouse        Craft-repair          Husband
# 21908   Married-civ-spouse     Exec-managerial          Husband
# 18864   Married-civ-spouse   Handlers-cleaners          Husband
# 4139         Never-married       Other-service        Own-child
# 22434             Divorced      Prof-specialty    Not-in-family
# 24616   Married-civ-spouse      Prof-specialty          Husband
# 23015   Married-civ-spouse               Sales          Husband
# 17531        Never-married                   ?        Own-child
# 18928   Married-civ-spouse        Craft-repair          Husband
# 20990             Divorced        Adm-clerical        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 11357                White   Female             0             0
# 27665                White     Male             0             0
# 19293                White   Female             0             0
# 9305                 White     Male             0             0
# 7115                 White   Female             0             0
# 7885                 White     Male             0             0
# 8399                 White     Male             0             0
# 31258                White     Male             0             0
# 22341                White     Male             0             0
# 26130                White     Male             0             0
# 3320                 White   Female             0             0
# 12175                White   Female             0             0
# 21624                White     Male             0          1887
# 10839                Black   Female             0             0
# 1201                 White     Male             0             0
# 25597                White     Male             0             0
# 1219                 White     Male             0             0
# 13803                White     Male             0             0
# 20504                White     Male             0             0
# 21062                White     Male             0             0
# 6132                 White     Male             0             0
# 30926                White     Male             0             0
# 28780                White   Female             0             0
# 7442                 White     Male          2354             0
# 7551                 White   Female             0             0
# 27022                White     Male             0          1485
# 27703                White     Male             0             0
# 537                  White     Male             0             0
# 13512                White   Female             0             0
# 15654                White     Male          7298             0
# ...                    ...      ...           ...           ...
# 4604                 White   Female             0             0
# 7780                 White     Male             0             0
# 28159                White   Female             0             0
# 12991                White     Male          1173             0
# 17924                White     Male             0             0
# 27074                White     Male             0             0
# 13886                White     Male             0             0
# 22557                White     Male             0             0
# 7171                 White   Female             0             0
# 29426                White     Male         15024             0
# 1608                 White     Male             0             0
# 5786    Asian-Pac-Islander     Male             0             0
# 14972                White     Male             0             0
# 14548                White   Female             0             0
# 22447                White     Male          7298             0
# 6383                 White     Male             0          2392
# 20831                White   Female             0             0
# 21441   Asian-Pac-Islander     Male             0             0
# 8586                 White     Male             0             0
# 7390                 Black     Male             0             0
# 7064                 White     Male             0             0
# 21908                White     Male             0             0
# 18864                White     Male             0             0
# 4139                 White     Male             0             0
# 22434                White     Male             0             0
# 24616                White     Male             0             0
# 23015                White     Male             0          1887
# 17531                White     Male             0             0
# 18928                White     Male             0             0
# 20990                White   Female             0             0
#
#        hours-per-week  native-country   class
# 11357              40   United-States   <=50K
# 27665              35   United-States   <=50K
# 19293              40   United-States   <=50K
# 9305               40     Puerto-Rico   <=50K
# 7115               25   United-States   <=50K
# 7885               45   United-States   <=50K
# 8399               40   United-States   <=50K
# 31258              35          Mexico   <=50K
# 22341              60   United-States   <=50K
# 26130              50   United-States    >50K
# 3320               40   United-States   <=50K
# 12175              40   United-States   <=50K
# 21624              55   United-States    >50K
# 10839              15   United-States   <=50K
# 1201               50   United-States    >50K
# 25597              20   United-States   <=50K
# 1219               40   United-States    >50K
# 13803              40   United-States    >50K
# 20504              30   United-States   <=50K
# 21062              40               ?   <=50K
# 6132               70   United-States   <=50K
# 30926              18   United-States   <=50K
# 28780              40   United-States   <=50K
# 7442               40   United-States   <=50K
# 7551               40   United-States   <=50K
# 27022              40   United-States    >50K
# 27703              50   United-States   <=50K
# 537                40   United-States   <=50K
# 13512              18   United-States   <=50K
# 15654              50   United-States    >50K
# ...               ...             ...     ...
# 4604               35   United-States   <=50K
# 7780               50   United-States   <=50K
# 28159              40   United-States    >50K
# 12991              40   United-States   <=50K
# 17924              50   United-States   <=50K
# 27074              40   United-States   <=50K
# 13886              40   United-States   <=50K
# 22557              99   United-States   <=50K
# 7171                8   United-States   <=50K
# 29426              40   United-States    >50K
# 1608               40   United-States   <=50K
# 5786               42           China   <=50K
# 14972              40          Mexico   <=50K
# 14548              38   United-States   <=50K
# 22447              40   United-States    >50K
# 6383               50   United-States    >50K
# 20831              48   United-States   <=50K
# 21441              47            Iran   <=50K
# 8586               40   United-States   <=50K
# 7390               40   United-States   <=50K
# 7064               50   United-States    >50K
# 21908              52   United-States    >50K
# 18864              55   United-States   <=50K
# 4139               40   United-States   <=50K
# 22434              40   United-States   <=50K
# 24616              56   United-States    >50K
# 23015              40   United-States    >50K
# 17531              40   United-States   <=50K
# 18928              40        Columbia   <=50K
# 20990              37   United-States   <=50K
#
# [32561 rows x 15 columns]

# %%
classes = data['class']

# %%
unclassified_data = data.drop('class', 1)

# %% [markdown]
# We want to split data between categorical and continuous data

# %%
categorical_cols = [
        'workclass',
        'education',
        'marital-status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'native-country',
       ]
categorical_data = unclassified_data[categorical_cols]

# %%
non_categorical_cols = [col for col in cols if col not in categorical_cols and col != 'class']

# %%
continuous_data = unclassified_data[non_categorical_cols]

# %% [markdown]
# We want to avoid overfitting on the training set. For this reason, we remove the order relationship within categorical data. If these serve the classification, the classifier will rebuild them. Else, it will not be influenced. Use: get_dummies.

# %%
categorical_as_dummies = pd.get_dummies(categorical_data, prefix=categorical_cols)

# %%
[(col, unclassified_data[col].dtype) for col in unclassified_data.columns]
# Out:
# [('age', dtype('int64')),
#  ('workclass', dtype('O')),
#  ('fnlwgt', dtype('int64')),
#  ('education', dtype('O')),
#  ('education-num', dtype('int64')),
#  ('marital-status', dtype('O')),
#  ('occupation', dtype('O')),
#  ('relationship', dtype('O')),
#  ('race', dtype('O')),
#  ('sex', dtype('O')),
#  ('capital-gain', dtype('int64')),
#  ('capital-loss', dtype('int64')),
#  ('hours-per-week', dtype('int64')),
#  ('native-country', dtype('O'))]

# %%
classes_as_numbers = classes.replace(' <=50K', 0).replace(' >50K', 1)

# %% [markdown]
# Conveniently, Random Forest Bagging deals as well with categorical as with continuous data. For this reason, we can use a single classifier working on the whole data.

# %%
full_data = pd.concat([continuous_data, categorical_as_dummies], axis=1)

# %% [markdown]
# Let's use scikit-learn random forest implementation. We do a few tries for the trees max depth (limited "grid search"). We estimate it using the ROC AUC cross val score. 20-21 are the best values.

# %%
import scipy
from sklearn.ensemble import (AdaBoostClassifier, ExtraTreesClassifier,
                              GradientBoostingClassifier, RandomForestClassifier)

benchmarked_classifiers = [AdaBoostClassifier, ExtraTreesClassifier,
                           GradientBoostingClassifier, RandomForestClassifier]

bagging_param_grid = [
  {
      'n_estimators': [n for n in range(20, 100) if (n%3 == 0 or n%10 == 0)], 
       'criterion': ['gini', 'linear'], 
       'min_sample_leaf': [n for n in range(1, 50) if n%3 == 1],
       'njobs': [2],
       'random_state': [None, 0, 1, 2, 3, 4],
       'oob_score': [True, False]
  }
]

boosting_param_grid = [
    {
        'lol': 'lol'
    }
]

clf = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=400, subsample=1.0, 
                                 criterion='friedman_mse', min_samples_split=6, min_samples_leaf=1, 
                                 min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                 min_impurity_split=None, init=None, random_state=None, max_features=None, 
                                 verbose=0, max_leaf_nodes=None, warm_start=False, presort='auto')
clf.fit(full_data, classes_as_numbers)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=6,
#               min_weight_fraction_leaf=0.0, n_estimators=400,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %% [markdown]
# Since performance of Gradient Boosting are good, and better than Random Forests and Extremely Randomized Forests, we only keep this one.

# %%
print(list(zip(full_data.columns, clf.feature_importances_)))
# Out:
# [('age', 0.10206480778725541), ('fnlwgt', 0.13188088702608744), ('education-num', 0.065607222775722951), ('capital-gain', 0.10597754767555731), ('capital-loss', 0.096009691381413867), ('hours-per-week', 0.090860682616692723), ('workclass_ ?', 0.0), ('workclass_ Federal-gov', 0.0071405651217611018), ('workclass_ Local-gov', 0.01056237963971266), ('workclass_ Never-worked', 0.0), ('workclass_ Private', 0.0070893626486215108), ('workclass_ Self-emp-inc', 0.0072862032151652153), ('workclass_ Self-emp-not-inc', 0.01108158029582198), ('workclass_ State-gov', 0.0086382293741332546), ('workclass_ Without-pay', 0.0018957642907502833), ('education_ 10th', 0.00039726512104029237), ('education_ 11th', 0.00083324776801138687), ('education_ 12th', 0.00058530799246263602), ('education_ 1st-4th', 0.00050492873584257988), ('education_ 5th-6th', 0.00092028743984407804), ('education_ 7th-8th', 0.00026465097721238047), ('education_ 9th', 0.00050867965528338869), ('education_ Assoc-acdm', 0.0036895616646991369), ('education_ Assoc-voc', 0.0034160556455575274), ('education_ Bachelors', 0.0091430979677217042), ('education_ Doctorate', 0.0026585827585833281), ('education_ HS-grad', 0.0030570149333666707), ('education_ Masters', 0.0024771633319253979), ('education_ Preschool', 1.240101065079844e-05), ('education_ Prof-school', 0.0067097639222264095), ('education_ Some-college', 0.0030638574688574964), ('marital-status_ Divorced', 0.0019215605226254485), ('marital-status_ Married-AF-spouse', 0.0060759168987402461), ('marital-status_ Married-civ-spouse', 0.051823817981357045), ('marital-status_ Married-spouse-absent', 0.00081569685294717717), ('marital-status_ Never-married', 0.0027795514537733534), ('marital-status_ Separated', 0.0014562162228736783), ('marital-status_ Widowed', 0.0047306573741938375), ('occupation_ ?', 0.00034650769581504731), ('occupation_ Adm-clerical', 0.004360071600624172), ('occupation_ Armed-Forces', 0.0), ('occupation_ Craft-repair', 0.0050361282494522678), ('occupation_ Exec-managerial', 0.012904055758751825), ('occupation_ Farming-fishing', 0.007759617360253622), ('occupation_ Handlers-cleaners', 0.0046567219270873782), ('occupation_ Machine-op-inspct', 0.0034429126438628955), ('occupation_ Other-service', 0.0082813546962105106), ('occupation_ Priv-house-serv', 0.0007066986266213174), ('occupation_ Prof-specialty', 0.017906474298620023), ('occupation_ Protective-serv', 0.0078298282644611809), ('occupation_ Sales', 0.011430522947229141), ('occupation_ Tech-support', 0.0074145094584979953), ('occupation_ Transport-moving', 0.0027813526775658437), ('relationship_ Husband', 0.012322513684677308), ('relationship_ Not-in-family', 0.0040643877305310619), ('relationship_ Other-relative', 0.0019695492446774789), ('relationship_ Own-child', 0.003430713109376763), ('relationship_ Unmarried', 0.0041813099392155675), ('relationship_ Wife', 0.024752389956787121), ('race_ Amer-Indian-Eskimo', 0.002610586142123303), ('race_ Asian-Pac-Islander', 0.0033982652592418534), ('race_ Black', 0.0010626265188471002), ('race_ Other', 0.00027298775744676366), ('race_ White', 0.0046435873313059595), ('sex_ Female', 0.0038453187711617494), ('sex_ Male', 0.0066015109986292345), ('native-country_ ?', 0.00089932857464689844), ('native-country_ Cambodia', 0.0038254514700937865), ('native-country_ Canada', 0.0060549979630827224), ('native-country_ China', 0.002008778395051208), ('native-country_ Columbia', 0.0028219623891447216), ('native-country_ Cuba', 0.0021763463932546866), ('native-country_ Dominican-Republic', 0.0017637346007094428), ('native-country_ Ecuador', 0.0015095074682917608), ('native-country_ El-Salvador', 0.0), ('native-country_ England', 0.0044707466641842235), ('native-country_ France', 0.00066762279456128893), ('native-country_ Germany', 0.0038439585135660211), ('native-country_ Greece', 0.0018268328921186945), ('native-country_ Guatemala', 0.00019565896587894988), ('native-country_ Haiti', 0.0), ('native-country_ Holand-Netherlands', 0.0), ...

# %% [markdown]
# As we could guess, fnlwgt, capital loss and capital gain are fairly pertinent to describe data in order to guess the revenue. Some other columns are not very pertinent and could be removed in order to see if this improves results.

# %%
test = pd.read_csv(dir_path+'adult.test.txt', names=cols)
y_true = test['class'].replace(' <=50K.', 0).replace(' >50K.', 1)
test_categorical_data = test[categorical_cols]
test_continuous_data = test[non_categorical_cols]
test_categorical_as_dummies = pd.get_dummies(test_categorical_data, prefix=categorical_cols)
test_full_data = pd.concat([test_continuous_data, test_categorical_as_dummies], axis=1)
test_full_data.columns

full_data.columns

[(i, col) for i, col in enumerate(full_data.columns) if col not in test_full_data.columns]
# Out:
# [(81, 'native-country_ Holand-Netherlands')]

# %% [markdown]
# Unfortunately, no one is from the Netherlands in the test set. We add the dummy column Netherlands full of zeros at position 81 in the DataFrame.

# %%
test_full_data.insert(81, 'native-country_ Holand-Netherlands', [0]*len(test_full_data.index))

# %%
y_pred = clf.predict(test_full_data)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf, full_data, classes_as_numbers, scoring='roc_auc')
# Out:
# array([ 0.92518826,  0.92721748,  0.92982492])

# %%
comp = pd.concat([y_true, pd.DataFrame(y_pred)], axis=1)
comp.columns = ['t', 'p']

# To measure performance of the model, we use accuracy, precision
# and recall.
# It allows us to get an idea of the overfitting level of our model
# to tune hyperparameters accordingly.
# crossval score on the training set is not used here because the model
# is overfitting when used on a to small subset of the data, meaning
# that performance decreases when the best result on the test dataset
# is not yet reached.
# We used validation/train split of 0.3.
# Maybe with a smaller validation proportion it would be
# a better indicator.
unaccurate = comp['t'] != comp['p']
unaccurate_preds = np.where(unaccurate, comp['t'], np.nan)
unaccurate_preds = unaccurate_preds[~np.isnan(unaccurate_preds)]
accuracy = 1 - len(unaccurate_preds) / len(y_true)
print("accuracy: " + str(accuracy))
true_pos = ((comp['t'] + comp['p']) == 2).sum()
false_pos = (comp['p'] == 1).sum() - true_pos
false_negs = (comp['t'] == 1).sum() - true_pos
precision = true_pos / (true_pos + false_pos)
print("precision: " + str(precision))
recall = true_pos / (true_pos + false_negs)
print("recall: " + str(recall))
# Out:
# accuracy: 0.8770960014741109
# precision: 0.787293677982
# recall: 0.657306292252

# %% [markdown]
# Accuracy is very good, but precision is not as good, meaning that there is stil a lot of noise in the predicition. To diminish this noise, we can try to remove columns considered unuseful.
#
# Recall is quite low, meaning that we do not detect many positive >50K in proportion of all the positive. For this reason, we should consider applying transformations on the important continuous variables (fnlwgt, capital loss, capital gain) in order to zoom in on the important ranges, to make the Gradient Boosting learning more precise on this part of the data. We could for example exponentiate capital gain and capital loss, since it looks like highly positive values of these are correlated with high revenue.

# %% [markdown]
# Lets's save the best classifier, the predictions done on the test set and the metrics inn order to use them in the API

# %%
from sklearn.externals import joblib

joblib.dump(clf, dir_path+'gradient_boosting.joblib.pkl')
# Out:
# ['/Users/macbookpro/Documents/gradient_boosting.joblib.pkl']

# %%
import pickle

with open(dir_path + 'test_results.pkl', 'wb') as f:
    pickle.dump({'accuracy': accuracy, 'precision': precision, 'recall': recall}, f)

# %%
y_pred = pd.DataFrame(y_pred).replace(0, '<=50K').replace(1, '>50K')
y_pred.columns = ['classifier output']
df = pd.concat([test, y_pred], axis=1)


df.to_csv(dir_path + 'classifier_output.csv')
print(dir_path + 'classifier_output.csv')
# Out:
# /Users/macbookpro/Documents/classifier_output.csv
